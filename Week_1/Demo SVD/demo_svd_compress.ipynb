# %%
from matplotlib.pyplot import imread
import matplotlib.pyplot as plt
import numpy as np
import os
from numpy.linalg import eig
from numpy.linalg import inv
from numpy import diag

plt.rcParams['figure.figsize'] = [16, 8]

A = imread(os.path.join('dog.jpg'),'jpg')
print(A)
X= np.mean(A, -1)
img = plt.imshow(X)
img.set_cmap('gray')
plt.axis('off')
plt.show()
print (X.shape)
# Out:
# [[[135 178 212]
#   [136 176 211]
#   [134 172 208]
#   ...
#   [134 176 216]
#   [133 175 217]
#   [130 172 214]]
#
#  [[133 173 208]
#   [134 172 208]
#   [135 173 209]
#   ...
#   [136 175 216]
#   [133 175 217]
#   [130 172 214]]
#
#  [[138 174 210]
#   [140 176 212]
#   [142 177 215]
#   ...
#   [136 173 215]
#   [134 173 216]
#   [132 171 214]]
#
#  ...
#
#  [[248 247 243]
#   [248 247 243]
#   [248 247 243]
#   ...
#   [210 215 221]
#   [211 216 222]
#   [212 217 221]]
#
#  [[249 248 244]
#   [248 247 243]
#   [248 247 243]
#   ...
#   [209 214 220]
#   [210 215 221]
#   [211 216 220]]
#
#  [[249 248 244]
#   [248 247 243]
#   [248 247 243]
#   ...
#   [210 215 221]
#   [210 215 219]
#   [211 216 220]]]
# &lt;Figure size 1152x576 with 1 Axes&gt;
# (2000, 1500)

# %%
U, S, VT = np.linalg.svd(X,full_matrices=False)
S = np.diag(S)
print(X.shape)

j = 0
for r in (100,200):
    # Construct approximate image
    Xapprox = U[:,:r] @ S[0:r,:r] @ VT[:r,:]
    print ( U[:,:r].shape)
    plt.figure(j+1)
    j += 1
    img = plt.imshow(Xapprox)
    img.set_cmap('gray')
    plt.axis('off')
    plt.title('r = ' + str(r))
    plt.show()
# Out:
# (2000, 1500)
# (2000, 100)
# (2000, 200)

# %%
## f_ch01_ex02_2

plt.figure(1)
plt.semilogy(np.diag(S))
plt.title('Singular Values')
plt.show()
print (np.diag(S)[:10])
print (np.cumsum(np.diag(S)[:10]))
# print (np.sum(np.diag(S)[:10]))      
plt.figure(2)
plt.plot(np.cumsum(np.diag(S))/np.sum(np.diag(S)))
plt.title('Singular Values: Cumulative Sum')
plt.show()
# Out:
# [297616.6643944   61332.72793886  47926.78500211  26607.88295037
#   21642.44632809  17449.47967528  16386.6318009   15421.68328981
#   12522.96626429  11619.49689317]
# [297616.6643944  358949.39233325 406876.17733537 433484.06028574
#  455126.50661383 472575.98628911 488962.61809001 504384.30137983
#  516907.26764412 528526.76453729]
